# %%
# !pip3 install mecab-python3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mecab-python3
#   Downloading mecab_python3-1.0.8-cp39-cp39-macosx_10_9_x86_64.whl (513 kB)
#      |████████████████████████████████| 513 kB 424 kB/s eta 0:00:01
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-1.0.8
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# !pip3 install unidic-lite
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unidic-lite
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      |████████████████████████████████| 47.4 MB 583 kB/s eta 0:00:01
# Using legacy 'setup.py install' for unidic-lite, since package 'wheel' is not installed.
# Installing collected packages: unidic-lite
#     Running setup.py install for unidic-lite ... done
# Successfully installed unidic-lite-1.0.8
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import MeCab

# %%
mecab = MeCab.Tagger()

# %%
results = mecab.parse('私はPythonが好きです')

# %%
print(results)
# Out:
# 私	ワタクシ	ワタクシ	私-代名詞	代名詞			0
# は	ワ	ハ	は	助詞-係助詞
# Python	Python	Python	Python	名詞-普通名詞-一般			0
# が	ガ	ガ	が	助詞-格助詞
# 好き	スキ	スキ	好き	形状詞-一般			2
# です	デス	デス	です	助動詞	助動詞-デス	終止形-一般
# EOS

# %%
# !pip3 install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp39-cp39-macosx_10_9_x86_64.whl (161 kB)
#      |████████████████████████████████| 161 kB 504 kB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp39-cp39-macosx_10_12_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 631 kB/s eta 0:00:01
# Collecting numpy>=1.6.1
#   Downloading numpy-1.26.2-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 772 kB/s eta 0:00:01
# Collecting pillow
#   Downloading Pillow-10.1.0-cp39-cp39-macosx_10_10_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 618 kB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.0-cp39-cp39-macosx_10_9_x86_64.whl (257 kB)
#      |████████████████████████████████| 257 kB 740 kB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.46.0-cp39-cp39-macosx_10_9_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 810 kB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (2.8.2)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_10_9_x86_64.whl (68 kB)
#      |████████████████████████████████| 68 kB 715 kB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 750 kB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: numpy, pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib, wordcloud
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.46.0 importlib-resources-6.1.1 kiwisolver-1.4.5 matplotlib-3.8.2 numpy-1.26.2 pillow-10.1.0 pyparsing-3.1.1 wordcloud-1.9.2
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from wordcloud import WordCloud

# %%
text = WordCloud.__doc__

# %%
wc = WordCloud(width=480, height=320)

# %%
wc.generate(text)

# %%
wc.to_file('sample.png')

# %%
plt.imshow(wc)
