# %%
# !pip3 install mecab-python3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mecab-python3 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (1.0.8)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# !pip3 install unidic-lite
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: unidic-lite in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (1.0.8)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import MeCab

# %%
mecab = MeCab.Tagger()

# %%
results = mecab.parse('私はPythonが好きです')

# %%
print(results)
# Out:
# 私	ワタクシ	ワタクシ	私-代名詞	代名詞			0
# は	ワ	ハ	は	助詞-係助詞
# Python	Python	Python	Python	名詞-普通名詞-一般			0
# が	ガ	ガ	が	助詞-格助詞
# 好き	スキ	スキ	好き	形状詞-一般			2
# です	デス	デス	です	助動詞	助動詞-デス	終止形-一般
# EOS

# %%
# !pip3 install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (1.9.2)
# Requirement already satisfied: pillow in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: matplotlib in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from wordcloud) (3.8.2)
# Requirement already satisfied: numpy>=1.6.1 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (4.46.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (6.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/kyutoson/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from wordcloud import WordCloud

# %%
text = WordCloud.__doc__

# %%
wc = WordCloud(width=480, height=320)

# %%
wc.generate(text)

# %%
wc.to_file('sample.png')

# %%
plt.imshow(wc)

# %%
font_path = 'ヒラギノ角ゴシック W5.ttc'

# %%
wakati = MeCab.Tagger('-Owakati')

# %%
text = 'みなさん、こんにちは！きゅうとです。私はPythonが好きです。'
results = wakati.parse(text)
print(results)
# Out:
# 'みな さん 、 こんにちは ！ きゅう と です 。 私 は Python が 好き です 。 \n'

# %%
wc = WordCloud(width=480, height=320, background_color='white', font_path=font_path)
wc.generate(wakati.parse(text))
wc.to_file('wcjp1.png')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/kyutoson/Desktop/G's Academy/kadai_php01/wordCloudJapanese.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/Users/kyutoson/Desktop/G%27s%20Academy/kadai_php01/wordCloudJapanese.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> wc = WordCloud(width=480, height=320, background_color='white', font_path=font_path)
# ----> <a href='vscode-notebook-cell:/Users/kyutoson/Desktop/G%27s%20Academy/kadai_php01/wordCloudJapanese.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> wc.generate(wakati.parse(text))
#       <a href='vscode-notebook-cell:/Users/kyutoson/Desktop/G%27s%20Academy/kadai_php01/wordCloudJapanese.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> wc.to_file('wcjp1.png')
#
# File ~/Library/Python/3.9/lib/python/site-packages/wordcloud/wordcloud.py:639, in WordCloud.generate(self, text)
#     624 def generate(self, text):
#     625     """Generate wordcloud from text.
#     626
#     627     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     637     self
#     638     """
# --> 639     return self.generate_from_text(text)
#
# File ~/Library/Python/3.9/lib/python/site-packages/wordcloud/wordcloud.py:621, in WordCloud.generate_from_text(self, text)
#     604 """Generate wordcloud from text.
#     605
#     606 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618 self
#     619 """
#     620 words = self.process_text(text)
# --> 621 self.generate_from_frequencies(words)
#     622 return self
#
# File ~/Library/Python/3.9/lib/python/site-packages/wordcloud/wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# --> 453     self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                    max_font_size=self.height)
#     455     # find font sizes
#     456     sizes = [x[1] for x in self.layout_]
#
# File ~/Library/Python/3.9/lib/python/site-packages/wordcloud/wordcloud.py:503, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     500 tried_other_orientation = False
#     501 while True:
#     502     # try to find a position
# --> 503     font = ImageFont.truetype(self.font_path, font_size)
#     504     # transpose font optionally
#     505     transposed_font = ImageFont.TransposedFont(
#     506         font, orientation=orientation)
#
# File ~/Library/Python/3.9/lib/python/site-packages/PIL/ImageFont.py:797, in truetype(font, size, index, encoding, layout_engine)
#     794     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     796 try:
# --> 797     return freetype(font)
#     798 except OSError:
#     799     if not is_path(font):
#
# File ~/Library/Python/3.9/lib/python/site-packages/PIL/ImageFont.py:794, in truetype.<locals>.freetype(font)
#     793 def freetype(font):
# --> 794     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File ~/Library/Python/3.9/lib/python/site-packages/PIL/ImageFont.py:226, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     224                 load_from_bytes(f)
#     225             return
# --> 226     self.font = core.getfont(
#     227         font, size, index, encoding, layout_engine=layout_engine
#     228     )
#     229 else:
#     230     load_from_bytes(font)
#
# OSError: cannot open resource
